# %% [markdown]
# ## Impor Liberaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv('customer_retention.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
pd.set_option('display.max_columns', None)
data.head(5)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.shape
# Out:
# (269, 71)

# %% [markdown]
# ## Columns Renamed As:

# %% [markdown]
# 1 Gender of respondent':'Gender'
#
# 2 How old are you? ':'Age',
#
# 3 Which city do you shop online from?':'City'
#
# 4 What is the Pin Code of where you shop online from?': 'Pin',
#
# 5 Since How Long You are Shopping Online ?': 'Years'
#
# 6 How many times you have made an online purchase in the past 1 year?': 'Number_of_Times',
#
# 7 How do you access the internet while shopping on-line?': 'Access_through',
#
# 8 Which device do you use to access the online shopping?':'Device',
#
# 9 What is the screen size of your mobile device?\t\t\t\t\t\t':'Screen_Size',
#
# 10 What is the operating system (OS) of your device?\t\t\t\t': 'Operating_System',
#
# 11 What browser do you run on your device to access the website?\t\t\t ': 'Browser',
#
# 12 Which channel did you follow to arrive at your favorite online store for the first time?':'First_Channel
#
# 13 After first visit, how do you reach the online retail store?\t\t\t\t':'After_First_Channel',
#
# '14 How much time do you explore the e- retail store before making a purchase decision?  ':'Explore_Time'
# '15 What is your preferred payment Option?\t\t\t\t\t': 'Preferable_Payment',
#
# '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t':'Abandon_Frequency',
#
# '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t':'Abaondon_Reason'
#
# '18 The content on the website must be easy to read and understand':'Easy_Content',
#
# '19 Information on similar product to the one highlighted  is important for product comparison':'Similar_product_comparison_important',
#
# '20 Complete information on listed seller and product being offered is important for purchase decision.':'Complete_information_important',
#
# '21 All relevant information on listed products must be stated clearly': 'Relevent_Info_Clear',
#
# '22 Ease of navigation in website': 'Easy_Navigation',
#
# '23 Loading and processing speed': 'Speed',
#
# '24 User friendly Interface of the website': 'User_Friendly',
#
# '25 Convenient Payment methods': 'Convenient_Payment',
#
# '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust_Transaction_Time',
#
# '27 Empathy (readiness to assist with queries) towards the customers':'Empathy',
#
# '28 Being able to guarantee the privacy of the customer': 'Privacy_Gaurantee',
#
# '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Responsiveness_Various_Channel',
#
# '30 Online shopping gives monetary benefit and discounts': 'Benefits_Discounts',
#
# '31 Enjoyment is derived from shopping online': 'Enjoyable',
#
# '32 Shopping online is convenient and flexible': 'Convenient_Flexible',
#
# '33 Return and replacement policy of the e-tailer is important for purchase decision': 'Return_Replacement_Policy_Important',
#
# '34 Gaining access to loyalty programs is a benefit of shopping online': 'Loyalty_Benefit',
#
# '35 Displaying quality Information on the website improves satisfaction of customers': 'Information_Quality_Satisfaction',
#
# '36 User derive satisfaction while shopping on a good quality website or application': 'Website_Quality_Satisfaction',
#
# '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net_Benefit_Satisfaction',
#
# '38 User satisfaction cannot exist without trust': 'User_satisfaction_with_trust',
#
# '39 Offering a wide variety of listed product in several category': 'Wide_Varieties',
#
# '40 Provision of complete and relevant product information': ' complete_relevant_product_information',
#
# '41 Monetary savings': 'Monetary_savings',
#
# '42 The Convenience of patronizing the online retailer': 'Convenience_patronizing_online_retailer',
#
# '43 Shopping on the website gives you the sense of adventure':'Adventure',
#
# '44 Shopping on your preferred e-tailer enhances your social status': 'preferred_e-tailer_enhances_social_status',
#
# '45 You feel gratification shopping on your favorite e-tailer': 'gratification_shopping_favorite_e-tailer',
#
# '46 Shopping on the website helps you fulfill certain roles': 'Shopping_online_fulfill_certain_roles',
#
# '47 Getting value for money spent':'Value_for_money'

# %% [markdown]
# #### Rename the columns

# %%
df = data.rename(columns = {'1Gender of respondent':'Gender','2 How old are you? ':'Age', '3 Which city do you shop online from?':'City', '4 What is the Pin Code of where you shop online from?': 'Pin', 
                        '5 Since How Long You are Shopping Online ?': 'Years','6 How many times you have made an online purchase in the past 1 year?': 'Number_of_Times_per_year', '7 How do you access the internet while shopping on-line?': 'Access_through',
                      '8 Which device do you use to access the online shopping?':'Device','9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'Screen_Size', '10 What is the operating system (OS) of your device?\t\t\t\t                                          ': 'Operating_System',
                       '11 What browser do you run on your device to access the website?\t\t\t                                                          ': 'Browser','12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'First_Channel', '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ': 'After_First_Channel',
                        '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ': 'Explore_Time', '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ': 'Preferable_Payment','16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'Abandon_Frequency',
                        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'Abaondon_Reason', '18 The content on the website must be easy to read and understand':'Easy_Content',
                        '19 Information on similar product to the one highlighted  is important for product comparison':'Similar_product_comparison_important', '20 Complete information on listed seller and product being offered is important for purchase decision.':'Complete_information_important', '21 All relevant information on listed products must be stated clearly': 'Relevent_Info_Clear',
                        '22 Ease of navigation in website': 'Easy_Navigation', '23 Loading and processing speed': 'Speed','24 User friendly Interface of the website': 'User_Friendly',
                       '25 Convenient Payment methods': 'Convenient_Payment', '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust_Transaction_Time','27 Empathy (readiness to assist with queries) towards the customers':'Empathy', '28 Being able to guarantee the privacy of the customer': 'Privacy_Gaurantee',
                       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Responsiveness_Various_Channel', '30 Online shopping gives monetary benefit and discounts': 'Benefits_Discounts', '31 Enjoyment is derived from shopping online': 'Enjoyable','32 Shopping online is convenient and flexible': 'Convenient_Flexible', '33 Return and replacement policy of the e-tailer is important for purchase decision': 'Return_Replacement_Policy_Important',
                       '34 Gaining access to loyalty programs is a benefit of shopping online': 'Loyalty_Benefit', '35 Displaying quality Information on the website improves satisfaction of customers': 'Information_Quality_Satisfaction', '36 User derive satisfaction while shopping on a good quality website or application': 'Website_Quality_Satisfaction', '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net_Benefit_Satisfaction', 
                       '38 User satisfaction cannot exist without trust': 'User_satisfaction_with_trust', '39 Offering a wide variety of listed product in several category': 'Wide_Varieties', '40 Provision of complete and relevant product information': ' complete_relevant_product_information', '41 Monetary savings': 'Monetary_savings', '42 The Convenience of patronizing the online retailer': 'Convenience_patronizing_online_retailer', '43 Shopping on the website gives you the sense of adventure':
                      'Adventure', '44 Shopping on your preferred e-tailer enhances your social status': 'preferred_e-tailer_enhances_social_status', '45 You feel gratification shopping on your favorite e-tailer': 'gratification_shopping_favorite_e-tailer', '46 Shopping on the website helps you fulfill certain roles': 'Shopping_online_fulfill_certain_roles', '47 Getting value for money spent':'Value_for_money'})

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                           --------------  -----
#  0   Gender                                                                                                                                                           269 non-null    object
#  1   Age                                                                                                                                                              269 non-null    object
# ...

# %% [markdown]
# #### Unique Values of each column

# %%
pd.DataFrame(df.nunique()).head(35)
# Out:
#                                        0
# Gender                                 2
# Age                                    5
# City                                  11
# Pin                                   39
# Years                                  5
# Number_of_Times_per_year               6
# Access_through                         4
# Device                                 4
# Screen_Size                            4
# Operating_System                       3
# Browser                                4
# First_Channel                          3
# After_First_Channel                    5
# Explore_Time                           5
# Preferable_Payment                     3
# Abandon_Frequency                      4
# Abaondon_Reason                        5
# Easy_Content                           4
# Similar_product_comparison_important   4
# Complete_information_important         5
# Relevent_Info_Clear                    4
# Easy_Navigation                        4
# ...

# %%
pd.DataFrame(df.nunique()).tail(36)
# Out:
#                                                      0
# Website_Quality_Satisfaction                         3
# Net_Benefit_Satisfaction                             4
# User_satisfaction_with_trust                         5
# Wide_Varieties                                       4
#  complete_relevant_product_information               4
# Monetary_savings                                     4
# Convenience_patronizing_online_retailer              3
# Adventure                                            5
# preferred_e-tailer_enhances_social_status            5
# gratification_shopping_favorite_e-tailer             5
# Shopping_online_fulfill_certain_roles                5
# Value_for_money                                      3
# From the following, tick any (or all) of the on...   9
# Easy to use website or application                  10
# Visual appealing web-page layout                    10
# Wild variety of product on offer                     9
# ...

# %%
#df.select_dtypes(include='object').columns

# %%
df[select]
# Out:
#      Gender                 Age           City          Years Screen_Size  \
# 0      Male         31-40 years          Delhi  Above 4 years      Others
# 1    Female         21-30 years          Delhi  Above 4 years  4.7 inches
# 2    Female         21-30 years  Greater Noida      3-4 years  5.5 inches
# 3      Male         21-30 years        Karnal       3-4 years  5.5 inches
# 4    Female         21-30 years     Bangalore       2-3 years  4.7 inches
# ..      ...                 ...            ...            ...         ...
# 264  Female         21-30 years          Solan      1-2 years  5.5 inches
# 265  Female         31-40 years      Ghaziabad      1-2 years      Others
# 266  Female         41-50 yaers     Bangalore       2-3 years      Others
# 267  Female  Less than 20 years          Solan      2-3 years  5.5 inches
# 268  Female         41-50 yaers      Ghaziabad      2-3 years  5.5 inches
#
#          Device        Browser
# 0       Desktop  Google chrome
# ...

# %%
def label_function(val):                                                      #Sharing % Number of countries in differet region
    return f'{val / 100 * len(data):.0f}\n{val:.0f}%'
plt.subplots(ncols=1, figsize=(10, 15))
df.groupby('Device').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 15},
                                 colors=['darkgrey', 'purple']).set_ylabel('Age', size=15)
plt.show()

# %% [markdown]
# ###
# * 52% i.e is the highest in the group of device has used to search online or shoping online as the smartphone is most compatible device as compared to Laptop and Desktop.
# * Tablet is the least used among this. Most of the people prefer to use desktop, laptop or phones.

# %%
df.head(2)
# Out:
#    Gender          Age   City     Pin          Years     Number_of_Times  \
# 0    Male  31-40 years  Delhi  110009  Above 4 years         31-40 times
# 1  Female  21-30 years  Delhi  110030  Above 4 years  41 times and above
#
#   Access_through      Device Screen_Size       Operating_System  \
# 0        Dial-up     Desktop      Others  Window/windows Mobile
# 1          Wi-Fi  Smartphone  4.7 inches                IOS/Mac
#
#          Browser  First_Channel After_First_Channel       Explore_Time  \
# 0  Google chrome  Search Engine       Search Engine          6-10 mins
# 1  Google chrome  Search Engine     Via application  more than 15 mins
#
#                    Preferable_Payment Abandon_Frequency  \
# 0  E-wallets (Paytm, Freecharge etc.)         Sometimes
# 1                  Credit/Debit cards   Very frequently
#
#              Abaondon_Reason        Easy_Content  \
# 0              Lack of trust           Agree (4)
# 1  Promo code not applicable  Strongly agree (5)
#
# ...

# %%
df['Device'].unique()
# Out:
# array(['Desktop', 'Smartphone', 'Tablet', 'Laptop'], dtype=object)

# %%
def label_function(val):                                                      #Sharing % Number of countries in differet region
    return f'{val / 100 * len(data):.0f}\n{val:.0f}%'
plt.subplots(ncols=1, figsize=(10, 15))
df.groupby('Age').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 15},
                                 colors=['darkgrey', 'purple']).set_ylabel('Region', size=15)
plt.show()

# %% [markdown]
# ###
# * Maximum number of people of age grooup 31 to 41 years old are there
# * And least percentage sharing are the age group of above 51 years as they are least interested in shoping and searching online

# %%
variables_1 = ['Gender','Age', 'City', 'Years','Number_of_Times_per_year',  'Screen_Size', 'Access_through', 'Device', 'Screen_Size','Operating_System', 'Browser', 'First_Channel', 
         'After_First_Channel', 'Explore_Time', 'Preferable_Payment', 'Abaondon_Reason']

# %%
color = sns.color_palette("husl", 8)

# %%
cols = 3                                                         #we can see the frequency ditribution here
rows = 6

num_cols = df[variables_1].select_dtypes(include='object').columns
fig = plt.figure( figsize=(cols*6, rows*4))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot( ax = ax, y = df[col], color=['r', 'b'], alpha = .8, hue = df['Gender'], multiple='dodge')
    
    #plt.yticks(fontsize=15)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# ### Counting of shopping online
# * Mostly there are females, males are less than 50% of female.
# * Mostly there are 31 to 40 years old Males group and 21 to 30 year old Female groups
# * DelhiNCR have the highest mnumber of users where highest number of Female users are from Greater Noida and Highest number of Male in Delhi.
# * Most of the people shopping online more than 4 years.
# * Most of the time "less than 10 times" have made an online purchase in the past 1 year.
# * Mostly uses mobile internet rather than wifi or dial-up for online shopping.
# * Males and Females both are uses smartphones mostly for shoping online.
# * Most number of people prefer window and mobile operating system.
# * Google is the maximum used browser.
# * People follow seartch engine to arrive at favorite online store for the first time as compared to content marketing and Display Adverts.
# * Payment option via Credit Crad/Debit Card are preferd more.
# * Better alternative offer is the reason of abandon mostly.

# %%
variables_2 = ['Complete_information_important', 'Relevent_Info_Clear','Easy_Navigation', 'Speed', 'User_Friendly', 'Convenient_Payment','Trust_Transaction_Time', 'Empathy', 'Privacy_Gaurantee',
       'Responsiveness_Various_Channel', 'Benefits_Discounts', 'Enjoyable','Convenient_Flexible', 'Return_Replacement_Policy_Important','Loyalty_Benefit', 'Information_Quality_Satisfaction',
       'Website_Quality_Satisfaction', 'Net_Benefit_Satisfaction','User_satisfaction_with_trust', 'Wide_Varieties',' complete_relevant_product_information', 'Monetary_savings',
       'Convenience_patronizing_online_retailer', 'Adventure','preferred_e-tailer_enhances_social_status','gratification_shopping_favorite_e-tailer',
       'Shopping_online_fulfill_certain_roles', 'Value_for_money']

# %%
cols = 3                                                         #we can see the frequency ditribution here
rows = 10

num_cols = df[variables_2].select_dtypes(include='object').columns
fig = plt.figure( figsize=(cols*6, rows*4))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot( ax = ax, y = df[col], color=['g', 'b'], alpha = .8, hue = df['Gender'], multiple='dodge')
    
    #plt.yticks(fontsize=15)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# ##### People Agree for:
#
# * The content on the website must be easy to read and understand.
# * Information on similar product to the one highlighted is important for product comparison.
# * Complete information on listed seller and product being offered is important for purchase decision.
# * All relevant information on listed products must be stated clearly.
# * Ease of navigation in website'
# * Loading and processing speed
# * User friendly Interface of the website
# * Convenient Payment methods
# * Trust that the online retail store will fulfill its part of the transaction at the stipulated time
# * Empathy (readiness to assist with queries) towards the customers
# * Being able to guarantee the privacy of the customer
# * Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)
# * Online shopping gives monetary benefit and discounts
# * Enjoyment is derived from shopping online'
# * Shopping online is convenient and flexible'
# * Return and replacement policy of the e-tailer is important for purchase decision
# * Gaining access to loyalty programs is a benefit of shopping online
# * Displaying quality Information on the website improves satisfaction of customers
# * User derive satisfaction while shopping on a good quality website or application
# * Net Benefit derived from shopping online can lead to users satisfaction
# * User satisfaction cannot exist without trust
# * Offering a wide variety of listed product in several category
# * Provision of complete and relevant product information
# * Monetary savings
# * The Convenience of patronizing the online retailer
# * Shopping on the website gives you the sense of adventure
# * value for money

# %%
variable_3 = ['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
       'Easy to use website or application','Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products','Fast loading website speed of website and application','Reliability of the website or application',
       'Quickness to complete purchase','Availability of several payment options', 'Speedy order delivery ','Privacy of customers’ information','Security of customer financial information',
       'Perceived Trustworthiness','Presence of online assistance through multi-channel','Longer time to get logged in (promotion, sales period)','Longer time in displaying graphics and photos (promotion, sales period)','Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)','Limited mode of payment on most products (promotion, sales period)','Longer delivery period', 'Change in website/Application design','Frequent disruption when moving from one page to another',
       'Website is as efficient as before','Which of the Indian online retailer would you recommend to a friend?']

# %%
cols = 2                                                         #we can see the frequency ditribution here
rows = 12

num_cols = df[variable_3].select_dtypes(include='object').columns
fig = plt.figure( figsize=(cols*10, rows*6))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot( ax = ax, y = df[col], color=['g', 'b'], alpha = .8, hue = df['Gender'], multiple='dodge')
    
    #plt.yticks(fontsize=15)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# ### 1. Amazon.com, 2 Flipkat.com, Snapdeal.com, Payment.com, Mytra.com , these sites having maximum votes as foloows:
#
# 1. 'From the following, tick any (or all) of the online retailers you have shopped from; >>>>  **All the sites**
# 2. 'Easy to use website or application' >>>> **All the sites**
# 3. 'Visual appealing web-page layout >>>> **Amazon and Flipkart**
# 4. 'Wild variety of product on offer' >>>> **Amazon and Flipkart**
# 5. 'Complete, relevant description information of products' >>>> **Amazon and Flipkart**
# 6. 'Fast loading website speed of website and application' >>>> **Amazon**
# 7. 'Reliability of the website or application', >>>> **Amazon**
# 8. 'Quickness to complete purchase' >>>> **Amazon**
# 9. 'Availability of several payment options' **Amazon and Flipkart**
# 10. 'Speedy order delivery ' >>>> **Amazon**
# 11. 'Privacy of customers’ information' >>>> **Amazon**
# 12. 'Security of customer financial information', >>>> **Amazon**
# 13. 'Perceived Trustworthiness' >>>>**Amazon**
# 14. 'Presence of online assistance through multi-channel' >>>> **Amazon**
# 15. 'Longer time to get logged in (promotion, sales period)' >>>> **Amazon**
# 16. 'Longer time in displaying graphics and photos (promotion, sales period)' >>>> **Amazon and Flipkart**
# 17. 'Late declaration of price (promotion, sales period)', >>>> **Myntra and then Snapdeal and Paytm**
# 18.  'Longer page loading time (promotion, sales period)' >>>> **Paytm and Snapdeal**
# 19. 'Limited mode of payment on most products (promotion, sales period)' >>>> **Snapdeal**
# 20. 'Longer delivery period' >>>> **Paytm**
# 21. 'Change in website/Application design' >>>> **Amazon**
# 22. 'Frequent disruption when moving from one page to another'>>>> **Snapdeal**
# 23. 'Website is as efficient as before' >>>> **Amazon**
# 24. 'Which of the Indian online retailer would you recommend to a friend? >>>> **Amazon**

# %%
plt.figure(figsize = (15, 8))
sns.histplot(binwidth=1,x="Explore_Time",hue='Gender',data=df,stat="count",multiple="dodge")
plt.show()

# %%
plt.figure(figsize = (15, 8))
sns.histplot(binwidth=1,x="City",hue='Gender',data=df,stat="count",multiple="dodge")
plt.show()

# %%
ax0 = fig.add_subplot(121)
sns.catplot(data=df, x="Device", y="City", hue="Gender", kind="swarm", height=5, aspect=3,  ax = ax0)


ax1 = fig.add_subplot(121)
sns.catplot(data=df, x="Browser", y="City", hue="Device", kind="swarm", height=5, aspect=3, ax = ax1)

ax2 = fig.add_subplot(121)
sns.catplot(data=df, x="Device", y="Age", hue="City", kind="swarm", height=5, aspect=3, ax = ax2)
plt.show()

# %% [markdown]
# ####  Graph 1
# * All the tablet users are male those whoe are shopping online.
# * In Delhi and Noida, Desktop users are genarally male those who are shopping online.
# * Female genrerally prefered either mobile or dekstop for shoping online.
#
# #### Graph 2
# * Mostly people uses google browser, people uses apple product who loves there privacy more uses Safari.
# * As comparison to the Google and Safari, opera and Firefox has less user friendly and due to this reason these browsers uses less.
# * As google is much user friendly in every device, it's mostly uses in every device

# %% [markdown]
# #### Graph 3
#
# * The age group of 21 to 30 years old uses mostly smartphones.
# * The age group of 31 to 40 years old uses mostly Lapptops.
# * As less than 20 years old are doing there schooling so they are usually operates mobiles, they generally don't need laptops and desktops.
